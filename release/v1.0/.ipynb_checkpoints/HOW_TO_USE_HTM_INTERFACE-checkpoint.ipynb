# %%
"""
Created on Mon Sep  9 09:33:14 2019

@author: Ming Jin
"""
import os
import json
import time
import datetime
import data_simulator
from itertools import islice
from nupic.data.file_record_stream import FileRecordStream
from htm_anomaly_detection import HTM
from nupic.engine import Network
from nupic.encoders import MultiEncoder, ScalarEncoder, DateEncoder

# %% [markdown]
# ### Example1. Run HTM network & save model (network status)

# %%
'''
parameters that we need to define：
    _TIMEOFDAY: internal buffer, see this: https://nupic.docs.numenta.org/1.0.3/api/algorithms/encoders.html
    _STREAM_BUFFER: The data stream buffer, which decides how many rows of data that should be writed into csv cache file each time
    _USE_SAVED_MODEL: Use saved model or not
'''
_TIMEOFDAY = (21,4)
_STREAM_BUFFER = 10
_USE_SAVED_MODEL = False


'''
Initialize HTM anomaly detection object
'''
htm = HTM(use_saved_model = _USE_SAVED_MODEL)


'''
Run the code below once to set encoders, SP, and TM parameters.
You should define these parameters by yourself:
    - minval (in scalarEncoderArgs): The minimum possible value for this input
    - maxval (in scalarEncoderArgs): The maximum possible value for this input
    - name (in scalarEncoderArgs): The name of this input
    - clipInput (in scalarEncoderArgs): Clip input if the value exceed the min/max values. 
After this, these parameters will be writed into seperate files.

* If you don't want to change these parameters anymore, then you should just read them from files 
and comment out the codes below in this cell.
'''
encoder_params = {
   'scalarEncoder1Args':{
     "minval": 0,
     "maxval": 100,
     "w": 21,
     "periodic": False,
     "n": 50,
     "radius": 0,
     "resolution": 0,
     "name": "value",
     "verbosity": 0,
     "clipInput": False,
     "forced": False,
   },
       
   'dateEncoder1Args':{
     "season": 0,
     "dayOfWeek": 0,
     "weekend": 0,
     "holiday": 0,
     "timeOfDay": _TIMEOFDAY,
     "customDays": 0,
     "name": "time",
     "forced": False
   },
       
   'scalarEncoder2Args':{
     "minval": 0,
     "maxval": 100,
     "w": 21,
     "periodic": False,
     "n": 50,
     "radius": 0,
     "resolution": 0,
     "name": "value",
     "verbosity": 0,
     "clipInput": False,
     "forced": False,
   },
   
   'dateEncoder2Args':{
     "season": 0,
     "dayOfWeek": 0,
     "weekend": 0,
     "holiday": 0,
     "timeOfDay": _TIMEOFDAY,
     "customDays": 0,
     "name": "time",
     "forced": False
   }
}

# save encoder parameters
if not os.path.exists('./temp'):
    os.makedirs('./temp')
    
htm.setEncoderParams('./temp/encoders.json', encoder_params)

_SP_PARAMS = {
   'SP':{
       "spatialImp": "cpp",
       "globalInhibition": 1,
       "columnCount": 2048,
       "inputWidth": 0,
       "numActiveColumnsPerInhArea": 40,
       "seed": 1956,
       "potentialPct": 0.8,
       "synPermConnected": 0.1,
       "synPermActiveInc": 0.0001,
       "synPermInactiveDec": 0.0005,
       "boostStrength": 0.0,
   }
}

_TM_PARAMS = {
   'TM':{
       "columnCount": 2048,
       "cellsPerColumn": 32,
       "inputWidth": 2048,
       "seed": 1960,
       "temporalImp": "cpp",
       "newSynapseCount": 20,
       "maxSynapsesPerSegment": 32,
       "maxSegmentsPerCell": 128,
       "initialPerm": 0.21,
       "permanenceInc": 0.1,
       "permanenceDec": 0.1,
       "globalDecay": 0.0,
       "maxAge": 0,
       "minThreshold": 9,
       "activationThreshold": 12,
       "outputType": "normal",
       "pamLength": 3,
   }
}

# save SP and TM parameters
htm.setEncoderParams('./temp/SP.json', _SP_PARAMS)
htm.setEncoderParams('./temp/TM.json', _TM_PARAMS)

# %%
'''
Load parameters from json files and build data stream reader to read data from cache.
* Maybe we just hard-code these path? There are many of them for users to define.
'''

scalarEncoder1Args = htm.getEncoderParams('./temp/encoders.json', 'scalarEncoder1Args')
dateEncoder1Args = htm.getEncoderParams('./temp/encoders.json', 'dateEncoder1Args')
scalarEncoder2Args = htm.getEncoderParams('./temp/encoders.json', 'scalarEncoder2Args')
dateEncoder2Args = htm.getEncoderParams('./temp/encoders.json', 'dateEncoder2Args')
SPArgs = htm.getEncoderParams('./temp/SP.json', 'SP')
TMArgs = htm.getEncoderParams('./temp/TM.json', 'TM')

input01_recordParams = {
  "scalarEncoderArgs": scalarEncoder1Args,
  "dateEncoderArgs": dateEncoder1Args,
}

input02_recordParams = {
  "scalarEncoderArgs": scalarEncoder2Args,
  "dateEncoderArgs": dateEncoder2Args,
}

# generate the first batch data to cache
data_simulator.getBatchData2csv(_STREAM_BUFFER, './temp/datacache01.csv', './temp/datacache02.csv')

# define the data souce
streamReader1 = FileRecordStream(streamID = './temp/datacache01.csv')
streamReader2 = FileRecordStream(streamID = './temp/datacache02.csv')

# %%
'''
create networks and tell them the source of data for prediction
'''
network01 = htm.createNetwork(datasource=streamReader1, recordParams=input01_recordParams, spatialParams=SPArgs, temporalParams=TMArgs)
network02 = htm.createNetwork(datasource=streamReader2, recordParams=input02_recordParams, spatialParams=SPArgs, temporalParams=TMArgs)

# %%
'''
Looping network.run() to get iterative prediction from data cache.

* network.run(1) means run this network once on next row of data in csv cache.

Before you run this cell, I already called data_simulator.getBatchData2csv once in the 
above cell to initialize the first batch of data. After this, the new data will be required 
by the while loop below when it reach the end of cache.
'''
iteration = 0
    
def run_network_once():
        fed_in_data01, anomalyLikelihood1 = htm.run(network01)
        fed_in_data02, anomalyLikelihood2 = htm.run(network02)
        runTime = data_simulator.getRunningTime('./temp/datacache01.csv', (iteration % _STREAM_BUFFER) + 3)
        print 'Running time:', runTime, 'fed_in_data01:', fed_in_data01,' anomaly likelihood:', anomalyLikelihood1
        print 'Running time:', runTime, 'fed_in_data02', fed_in_data02,' anomaly likelihood:', anomalyLikelihood2, '\n'
        time.sleep(1)
        
while(iteration < 500):
    if iteration == 0:
        run_network_once()
    elif iteration % _STREAM_BUFFER != 0:
        run_network_once()
    else:
        network01.regions["sensor"].getSelf().dataSource.rewind()
        network02.regions["sensor"].getSelf().dataSource.rewind()
        data_simulator.getBatchData2csv(_STREAM_BUFFER, './temp/datacache01.csv', './temp/datacache02.csv')
        run_network_once()
    iteration += 1

'''
Save the model when breaking from while loop.

You should define your button in SENSEI to break this while loop and save the model 
because we usually set looping as while(1) instead of while(iteration < n)
'''
if not os.path.exists('./models'):
    os.makedirs('./models')
    
htm.save_network(network01, './models/network1.nta')
htm.save_network(network02, './models/network2.nta')

print '\nComplete.'
# Out:
# Running time: 2019-09-09 01:00:00 fed_in_data01: 8.4  anomaly likelihood: 0
00:00 fed_in_data02 46.8  anomaly likelihood: 0.617784
#
# Running time: 2019-09-27 20:00:00 fed_in_data01: 5.5  anomaly likelihood: 0.851256
# Running time: 2019-09-27 20:00:00 fed_in_data02 46.8  anomaly likelihood: 0.635756
#
# Running time: 2019-09-27 21:00:00 fed_in_data01: 8.6  anomaly likelihood: 0.875537
# Running time: 2019-09-27 21:00:00 fed_in_data02 46.8  anomaly likelihood: 0.635756
#
# Running time: 2019-09-27 22:00:00 fed_in_data01: 7.0  anomaly likelihood: 0.896902
# Running time: 2019-09-27 22:00:00 fed_in_data02 46.8  anomaly likelihood: 0.617784
#
# Running time: 2019-09-27 23:00:00 fed_in_data01: 3.9  anomaly likelihood: 0.906525
# Running time: 2019-09-27 23:00:00 fed_in_data02 46.8  anomaly likelihood: 0.617784
#
# Running time: 2019-09-28 00:00:00 fed_in_data01: 7.4  anomaly likelihood: 0.915469
# Running time: 2019-09-28 00:00:00 fed_in_data02 46.8  anomaly likelihood: 0.670784
#
# Running time: 2019-09-28 01:00:00 fed_in_data01: 6.6  anomaly likelihood: 0.923754
# Running time: 2019-09-28 01:00:00 fed_in_data02 46.8  anomaly likelihood: 0.704374
#
# Running time: 2019-09-28 02:00:00 fed_in_data01: 7.2  anomaly likelihood: 0.923754
# Running time: 2019-09-28 02:00:00 fed_in_data02 46.7  anomaly likelihood: 0.581105
#
# Running time: 2019-09-28 03:00:00 fed_in_data01: 5.7  anomaly likelihood: 0.931407
# Running time: 2019-09-28 03:00:00 fed_in_data02 46.7  anomaly likelihood: 0.505918
#
# Running time: 2019-09-28 04:00:00 fed_in_data01: 4.3  anomaly likelihood: 0.938453
# Running time: 2019-09-28 04:00:00 fed_in_data02 46.7  anomaly likelihood: 0.505918
#
# Running time: 2019-09-28 05:00:00 fed_in_data01: 8.2  anomaly likelihood: 0.938453
# Running time: 2019-09-28 05:00:00 fed_in_data02 46.8  anomaly likelihood: 0.531925
#
# Running time: 2019-09-28 06:00:00 fed_in_data01: 5.7  anomaly likelihood: 0.944921
# Running time: 2019-09-28 06:00:00 fed_in_data02 46.8  anomaly likelihood: 0.505918
#
# Running time: 2019-09-28 07:00:00 fed_in_data01: 11.7  anomaly likelihood: 0.923754
# Running time: 2019-09-28 07:00:00 fed_in_data02 46.8  anomaly likelihood: 0.543707
#
# Running time: 2019-09-28 08:00:00 fed_in_data01: 8.6  anomaly likelihood: 0.886578
# Running time: 2019-09-28 08:00:00 fed_in_data02 46.8  anomaly likelihood: 0.505918
# Running time: 2019-09-28 09:00:00 fed_in_data01: 7.4  anomaly likelihood: 0.886578
# Running time: 2019-09-28 09:00:00 fed_in_data02 46.8  anomaly likelihood: 0.505918
#
# Running time: 2019-09-28 10:00:00 fed_in_data01: 10.9  anomaly likelihood: 0.875537
# Running time: 2019-09-28 10:00:00 fed_in_data02 46.8  anomaly likelihood: 0.588047
#
# Running time: 2019-09-28 11:00:00 fed_in_data01: 8.8  anomaly likelihood: 0.838
# Running time: 2019-09-28 11:00:00 fed_in_data02 46.8  anomaly likelihood: 0.624555
#
# Running time: 2019-09-28 12:00:00 fed_in_data01: 11.7  anomaly likelihood: 0.851256
# Running time: 2019-09-28 12:00:00 fed_in_data02 46.8  anomaly likelihood: 0.505918
#
# Running time: 2019-09-28 13:00:00 fed_in_data01: 6.1  anomaly likelihood: 0.838
# Running time: 2019-09-28 13:00:00 fed_in_data02 46.7  anomaly likelihood: 0.562476
#
# Running time: 2019-09-28 14:00:00 fed_in_data01: 6.3  anomaly likelihood: 0.809251
# Running time: 2019-09-28 14:00:00 fed_in_data02 46.7  anomaly likelihood: 0.562476
#
# Running time: 2019-09-28 15:00:00 fed_in_data01: 6.2  anomaly likelihood: 0.77757
# Running time: 2019-09-28 15:00:00 fed_in_data02 46.7  anomaly likelihood: 0.562476
#
# Running time: 2019-09-28 16:00:00 fed_in_data01: 9.8  anomaly likelihood: 0.77757
# Running time: 2019-09-28 16:00:00 fed_in_data02 46.8  anomaly likelihood: 0.562476
#
# Running time: 2019-09-28 17:00:00 fed_in_data01: 21.1  anomaly likelihood: 0.823997
# Running time: 2019-09-28 17:00:00 fed_in_data02 46.9  anomaly likelihood: 0.543707
#
# Running time: 2019-09-28 18:00:00 fed_in_data01: 10.5  anomaly likelihood: 0.823997
# Running time: 2019-09-28 18:00:00 fed_in_data02 46.8  anomaly likelihood: 0.543707
#
# Running time: 2019-09-28 19:00:00 fed_in_data01: 6.6  anomaly likelihood: 0.809251
# Running time: 2019-09-28 19:00:00 fed_in_data02 46.8  anomaly likelihood: 0.562476
#
# Running time: 2019-09-28 20:00:00 fed_in_data01: 5.9  anomaly likelihood: 0.77757
# Running time: 2019-09-28 20:00:00 fed_in_data02 46.8  anomaly likelihood: 0.599554
#
# Running time: 2019-09-28 21:00:00 fed_in_data01: 3.9  anomaly likelihood: 0.793771
# Running time: 2019-09-28 21:00:00 fed_in_data02 46.8  anomaly likelihood: 0.599554
#
# Running time: 2019-09-28 22:00:00 fed_in_data01: 6.1  anomaly likelihood: 0.77757
# Running time: 2019-09-28 22:00:00 fed_in_data02 46.8  anomaly likelihood: 0.599554
#
# Running time: 2019-09-28 23:00:00 fed_in_data01: 8.8  anomaly likelihood: 0.625325
# Running time: 2019-09-28 23:00:00 fed_in_data02 46.8  anomaly likelihood: 0.617784
#
# Running time: 2019-09-29 00:00:00 fed_in_data01: 11.1  anomaly likelihood: 0.646192
# Running time: 2019-09-29 00:00:00 fed_in_data02 46.8  anomaly likelihood: 0.670784
#
# Running time: 2019-09-29 01:00:00 fed_in_data01: 9.8  anomaly likelihood: 0.666629
# Running time: 2019-09-29 01:00:00 fed_in_data02 46.9  anomaly likelihood: 0.687774
#
# Running time: 2019-09-29 02:00:00 fed_in_data01: 22.1  anomaly likelihood: 0.51662
# Running time: 2019-09-29 02:00:00 fed_in_data02 46.9  anomaly likelihood: 0.704374
#
# Running time: 2019-09-29 03:00:00 fed_in_data01: 27.3  anomaly likelihood: 0.801602
# Running time: 2019-09-29 03:00:00 fed_in_data02 46.9  anomaly likelihood: 0.720556
#
# Running time: 2019-09-29 04:00:00 fed_in_data01: 8.6  anomaly likelihood: 0.919692
# Running time: 2019-09-29 04:00:00 fed_in_data02 46.9  anomaly likelihood: 0.76636
#
# Running time: 2019-09-29 05:00:00 fed_in_data01: 7.6  anomaly likelihood: 0.935004
# Running time: 2019-09-29 05:00:00 fed_in_data02 46.9  anomaly likelihood: 0.76636
#
# Running time: 2019-09-29 06:00:00 fed_in_data01: 6.4  anomaly likelihood: 0.919692
# Running time: 2019-09-29 06:00:00 fed_in_data02 46.9  anomaly likelihood: 0.807665
#
# Running time: 2019-09-29 07:00:00 fed_in_data01: 6.6  anomaly likelihood: 0.919692
# Running time: 2019-09-29 07:00:00 fed_in_data02 46.9  anomaly likelihood: 0.832544
#
# Running time: 2019-09-29 08:00:00 fed_in_data01: 6.7  anomaly likelihood: 0.947947
# Running time: 2019-09-29 08:00:00 fed_in_data02 46.9  anomaly likelihood: 0.807665
#
# Running time: 2019-09-29 09:00:00 fed_in_data01: 6.1  anomaly likelihood: 0.891828
# Running time: 2019-09-29 09:00:00 fed_in_data02 46.9  anomaly likelihood: 0.79442
#
# Running time: 2019-09-29 10:00:00 fed_in_data01: 8.4  anomaly likelihood: 0.891828
# Running time: 2019-09-29 10:00:00 fed_in_data02 46.9  anomaly likelihood: 0.720556
#
# Running time: 2019-09-29 11:00:00 fed_in_data01: 4.5  anomaly likelihood: 0.891828
# Running time: 2019-09-29 11:00:00 fed_in_data02 47.0  anomaly likelihood: 0.687774
#
# Running time: 2019-09-29 12:00:00 fed_in_data01: 7.0  anomaly likelihood: 0.831092
# Running time: 2019-09-29 12:00:00 fed_in_data02 47.0  anomaly likelihood: 0.670784
#
# Running time: 2019-09-29 13:00:00 fed_in_data01: 7.4  anomaly likelihood: 0.527687
# Running time: 2019-09-29 13:00:00 fed_in_data02 47.0  anomaly likelihood: 0.670784
#
# Running time: 2019-09-29 14:00:00 fed_in_data01: 6.4  anomaly likelihood: 0.724853
# Running time: 2019-09-29 14:00:00 fed_in_data02 47.0  anomaly likelihood: 0.670784
#
# Running time: 2019-09-29 15:00:00 fed_in_data01: 3.9  anomaly likelihood: 0.760666
# Running time: 2019-09-29 15:00:00 fed_in_data02 46.9  anomaly likelihood: 0.670784
#
# Running time: 2019-09-29 16:00:00 fed_in_data01: 4.1  anomaly likelihood: 0.760666
# Running time: 2019-09-29 16:00:00 fed_in_data02 46.9  anomaly likelihood: 0.670784
#
# Running time: 2019-09-29 17:00:00 fed_in_data01: 5.1  anomaly likelihood: 0.793771
# Running time: 2019-09-29 17:00:00 fed_in_data02 46.9  anomaly likelihood: 0.670784
#
# Running time: 2019-09-29 18:00:00 fed_in_data01: 2.9  anomaly likelihood: 0.863766
# Running time: 2019-09-29 18:00:00 fed_in_data02 46.9  anomaly likelihood: 0.720556
#
# Running time: 2019-09-29 19:00:00 fed_in_data01: 7.2  anomaly likelihood: 0.875537
# Running time: 2019-09-29 19:00:00 fed_in_data02 46.9  anomaly likelihood: 0.75157
#
# Running time: 2019-09-29 20:00:00 fed_in_data01: 4.5  anomaly likelihood: 0.886578
# Running time: 2019-09-29 20:00:00 fed_in_data02 46.9  anomaly likelihood: 0.820376
#
#
# Complete.

# %% [markdown]
# ### Example2. Use saved model to keep running on cache data

# %%
'''
Loading the saved model above and restore it to keep prediction & learning.

The data source will be the same as we defined above.

Notice that in HTM, the data source is associated with the network, and 
we should define that when we created the network, which is different from
LSTM where we feed data in actively. HTM network will use data generator 
(e.g., FileRecordStream) to automatically fetch the data from csv.

This is why we don't need to re-define our data source, spatial, and temporal params again
because these are the parts of 'model' we have saved.
'''

_USE_SAVED_MODEL = True
htm = HTM(use_saved_model = _USE_SAVED_MODEL)

scalarEncoder1Args = htm.getEncoderParams('./temp/encoders.json', 'scalarEncoder1Args')
dateEncoder1Args = htm.getEncoderParams('./temp/encoders.json', 'dateEncoder1Args')
scalarEncoder2Args = htm.getEncoderParams('./temp/encoders.json', 'scalarEncoder2Args')
dateEncoder2Args = htm.getEncoderParams('./temp/encoders.json', 'dateEncoder2Args')
SPArgs = htm.getEncoderParams('./temp/SP.json', 'SP')
TMArgs = htm.getEncoderParams('./temp/TM.json', 'TM')

input01_recordParams = {
  "scalarEncoderArgs": scalarEncoder1Args,
  "dateEncoderArgs": dateEncoder1Args,
}

input02_recordParams = {
  "scalarEncoderArgs": scalarEncoder2Args,
  "dateEncoderArgs": dateEncoder2Args,
}


model1 = './models/network1.nta'
model2 = './models/network2.nta'
network01 = htm.createNetwork(datasource=None, recordParams=input01_recordParams, spatialParams=None, temporalParams=None, model_path = model1)
network02 = htm.createNetwork(datasource=None, recordParams=input02_recordParams, spatialParams=None, temporalParams=None, model_path = model2)

# run the restored network on data from cache file
iteration = 0
    
def run_network_once():
        fed_in_data01, anomalyLikelihood1 = htm.run(network01)
        fed_in_data02, anomalyLikelihood2 = htm.run(network02)
        runTime = data_simulator.getRunningTime('./temp/datacache01.csv', (iteration % _STREAM_BUFFER) + 3)
        print 'Running time:', runTime, 'fed_in_data01:', fed_in_data01,' anomaly likelihood:', anomalyLikelihood1
        print 'Running time:', runTime, 'fed_in_data02', fed_in_data02,' anomaly likelihood:', anomalyLikelihood2, '\n'
        time.sleep(1)
        
while(iteration < 30):
    if iteration == 0:
        print 'frist part...'
        run_network_once()
    elif iteration % _STREAM_BUFFER != 0:
        print 'second part...'
        run_network_once()
    else:
        print 'update csv...'
        network01.regions["sensor"].getSelf().dataSource.rewind()
        network02.regions["sensor"].getSelf().dataSource.rewind()
        data_simulator.getBatchData2csv(_STREAM_BUFFER, './temp/datacache01.csv', './temp/datacache02.csv')
        run_network_once()
    iteration += 1
    
print '\nComplete.'
# Out:
# frist part...
# Running time: 2019-09-29 11:00:00 fed_in_data01: 8.6  anomaly likelihood: 0.82502
# Running time: 2019-09-29 11:00:00 fed_in_data02 47.0  anomaly likelihood: 0.877275
#
# second part...
# Running time: 2019-09-29 12:00:00 fed_in_data01: 4.5  anomaly likelihood: 0.850322
# Running time: 2019-09-29 12:00:00 fed_in_data02 47.0  anomaly likelihood: 0.889361
#
# second part...
# Running time: 2019-09-29 13:00:00 fed_in_data01: 8.2  anomaly likelihood: 0.850322
# Running time: 2019-09-29 13:00:00 fed_in_data02 47.0  anomaly likelihood: 0.889361
#
# second part...
# Running time: 2019-09-29 14:00:00 fed_in_data01: 4.9  anomaly likelihood: 0.873058
# Running time: 2019-09-29 14:00:00 fed_in_data02 47.0  anomaly likelihood: 0.889361
#
# second part...
# Running time: 2019-09-29 15:00:00 fed_in_data01: 3.9  anomaly likelihood: 0.862009
# Running time: 2019-09-29 15:00:00 fed_in_data02 47.0  anomaly likelihood: 0.889361
#
# second part...
# Running time: 2019-09-29 16:00:00 fed_in_data01: 5.5  anomaly likelihood: 0.862009
# Running time: 2019-09-29 16:00:00 fed_in_data02 46.9  anomaly likelihood: 0.889361
#
# second part...
# Running time: 2019-09-29 17:00:00 fed_in_data01: 15.0  anomaly likelihood: 0.850322
# Running time: 2019-09-29 17:00:00 fed_in_data02 47.0  anomaly likelihood: 0.877275
#
# second part...
# Running time: 2019-09-29 18:00:00 fed_in_data01: 5.9  anomaly likelihood: 0.837993
# Running time: 2019-09-29 18:00:00 fed_in_data02 47.0  anomaly likelihood: 0.835585
#
# second part...
# Running time: 2019-09-29 19:00:00 fed_in_data01: 8.4  anomaly likelihood: 0.850322
# Running time: 2019-09-29 19:00:00 fed_in_data02 46.9  anomaly likelihood: 0.785667
#
# second part...
# Running time: 2019-09-29 20:00:00 fed_in_data01: 7.2  anomaly likelihood: 0.82502
# Running time: 2019-09-29 20:00:00 fed_in_data02 46.9  anomaly likelihood: 0.767247
#
# update csv...
# Running time: 2019-09-29 21:00:00 fed_in_data01: 8.6  anomaly likelihood: 0.762917
# Running time: 2019-09-29 21:00:00 fed_in_data02 47.0  anomaly likelihood: 0.840578
#
# second part...
# Running time: 2019-09-29 22:00:00 fed_in_data01: 4.5  anomaly likelihood: 0.778546
# Running time: 2019-09-29 22:00:00 fed_in_data02 47.0  anomaly likelihood: 0.840578
#
# second part...
# Running time: 2019-09-29 23:00:00 fed_in_data01: 8.2  anomaly likelihood: 0.778546
# Running time: 2019-09-29 23:00:00 fed_in_data02 47.0  anomaly likelihood: 0.904082
#
# second part...
# Running time: 2019-09-30 00:00:00 fed_in_data01: 4.9  anomaly likelihood: 0.778546
# Running time: 2019-09-30 00:00:00 fed_in_data02 47.0  anomaly likelihood: 0.953049
#
# second part...
# Running time: 2019-09-30 01:00:00 fed_in_data01: 3.9  anomaly likelihood: 0.778546
# Running time: 2019-09-30 01:00:00 fed_in_data02 47.0  anomaly likelihood: 0.984939
#
# second part...
# Running time: 2019-09-30 02:00:00 fed_in_data01: 5.5  anomaly likelihood: 0.778546
# Running time: 2019-09-30 02:00:00 fed_in_data02 46.9  anomaly likelihood: 0.996114
#
# second part...
# Running time: 2019-09-30 03:00:00 fed_in_data01: 15.0  anomaly likelihood: 0.778546
# Running time: 2019-09-30 03:00:00 fed_in_data02 47.0  anomaly likelihood: 0.998184
#
# second part...
# Running time: 2019-09-30 04:00:00 fed_in_data01: 5.9  anomaly likelihood: 0.778546
# Running time: 2019-09-30 04:00:00 fed_in_data02 47.0  anomaly likelihood: 0.998512
#
# second part...
# Running time: 2019-09-30 05:00:00 fed_in_data01: 8.4  anomaly likelihood: 0.778546
# Running time: 2019-09-30 05:00:00 fed_in_data02 46.9  anomaly likelihood: 0.998512
#
# second part...
# Running time: 2019-09-30 06:00:00 fed_in_data01: 7.2  anomaly likelihood: 0.778546
# Running time: 2019-09-30 06:00:00 fed_in_data02 46.9  anomaly likelihood: 0.998512
#
# update csv...
# Running time: 2019-09-30 07:00:00 fed_in_data01: 6.4  anomaly likelihood: 0.811407
# Running time: 2019-09-30 07:00:00 fed_in_data02 47.2  anomaly likelihood: 0.893158
#
# second part...
# Running time: 2019-09-30 08:00:00 fed_in_data01: 3.7  anomaly likelihood: 0.82502
# Running time: 2019-09-30 08:00:00 fed_in_data02 47.1  anomaly likelihood: 0.914161
#
# second part...
# Running time: 2019-09-30 09:00:00 fed_in_data01: 4.1  anomaly likelihood: 0.811407
# Running time: 2019-09-30 09:00:00 fed_in_data02 47.1  anomaly likelihood: 0.868679
#
# second part...
# Running time: 2019-09-30 10:00:00 fed_in_data01: 14.3  anomaly likelihood: 0.750732
# Running time: 2019-09-30 10:00:00 fed_in_data02 47.1  anomaly likelihood: 0.855086
#
# second part...
# Running time: 2019-09-30 11:00:00 fed_in_data01: 11.6  anomaly likelihood: 0.766806
# Running time: 2019-09-30 11:00:00 fed_in_data02 47.1  anomaly likelihood: 0.754433
#
# second part...
# Running time: 2019-09-30 12:00:00 fed_in_data01: 8.6  anomaly likelihood: 0.782288
# Running time: 2019-09-30 12:00:00 fed_in_data02 47.1  anomaly likelihood: 0.60135
#
# second part...
# Running time: 2019-09-30 13:00:00 fed_in_data01: 10.5  anomaly likelihood: 0.699189
# Running time: 2019-09-30 13:00:00 fed_in_data02 47.1  anomaly likelihood: 0.504061
#
# second part...
# Running time: 2019-09-30 14:00:00 fed_in_data01: 4.1  anomaly likelihood: 0.716896
# Running time: 2019-09-30 14:00:00 fed_in_data02 47.1  anomaly likelihood: 0.520531
#
# second part...
# Running time: 2019-09-30 15:00:00 fed_in_data01: 7.0  anomaly likelihood: 0.716896
# Running time: 2019-09-30 15:00:00 fed_in_data02 47.1  anomaly likelihood: 0.520531
#
# second part...
# Running time: 2019-09-30 16:00:00 fed_in_data01: 8.4  anomaly likelihood: 0.750732
# Running time: 2019-09-30 16:00:00 fed_in_data02 47.1  anomaly likelihood: 0.520531
#
#
# Complete.
